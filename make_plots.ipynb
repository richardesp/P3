# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
seeds = [0.05, 0.15, 0.25, 0.5]
mse_tests = [68.97, 67.36, 61.84, 62.41]
mse_training = [73.38, 79.06, 84.30, 93.88]
plt.bar()
plt.legend(['Entrenamiento', 'Tests'])
ax.set_title('Comparación del MSE en entrenamiento y tests dado el Nº de neuronas')
ax.set_ylabel('MSE')
ax.set_xlabel('Topologías')
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt


# creating the dataset
data = {'C':20, 'C++':15, 'Java':30,
        'Python':35}

ccr = [91.33, 92.33, 91.67, 92.33, 92.67]
seeds = [1, 2, 3, 4, 5]

# creating the bar plot
plt.bar(seeds, ccr)

plt.xlabel("Seeds")
plt.ylabel("CCR")
plt.title("Comparación de resultados de CCR en tests en las distintas semillas")
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt

# set width of bar
barWidth = 0.25
fig = plt.subplots(figsize =(12, 8))

mse_tests = [88.93, 89.00, 88.00, 88.80]
mse_training = [87.78, 97.53, 99.82, 99.98]

# set height of bar
IT = [12, 30, 1, 8]
ECE = [28, 6, 16, 5]
CSE = [29, 3, 24, 25]

# Set position of bar on X axis
br1 = np.arange(len(mse_tests))
br2 = [x + barWidth for x in br1]

# Make the plot
plt.bar(br1, mse_tests, color ='r', width = barWidth,
    edgecolor ='grey', label ='Tests')
plt.bar(br2, mse_training, color ='g', width = barWidth,
    edgecolor ='grey', label ='Entrenamiento')

# Adding Xticks
plt.title('Comparación del CCR en entrenamiento y tests dado el Nº de neuronas')
plt.xlabel('Ratio de neuronas RBF', fontweight ='bold', fontsize = 15)
plt.ylabel('CCR ', fontweight ='bold', fontsize = 15)
plt.xticks([r + barWidth for r in range(len(mse_tests))],
['0.05', '0.15', '0.25', '0.5'])
plt.legend()
plt.show()

# %%
import seaborn as sns
import numpy as np

ax = sns.heatmap(np.array([[0.7643,  0.7750], # TP FP FN TN
       [0.2357 , 0.2250]]), annot=True, cmap='Blues', fmt='.2%')

ax.set_title('Matriz de confusión con heurística actualizada en mujeres en tests\n')

## Ticket labels - List must be in alphabetical order
ax.set_ylabel('Etiquetas reales')
ax.set_xlabel('Etiquetas predichas')
ax.xaxis.set_ticklabels(['0','1'])
ax.yaxis.set_ticklabels(['0','1'])

## Display the visualization of the Confusion Matrix.
plt.show()

# %%
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

sns.set()

# Create a dataframe --> eta, regularization : Nº coefficients
data = [[1, 0 + 1, 63], [0.1, 0 + 1, 142], [0.01, 0 + 1, 321], [0.001, 0 + 1, 409], [10e-10, 0 + 1, 443], [1, 1 + 1, 249], [0.1, 1 + 1, 271], [0.01, 1 + 1, 339], [0.001, 1 + 1, 406], [10e-10, 1 + 1, 444]]

df = pd.DataFrame(data, columns=['eta', 'Regularization', 'Nº coefficients'])
df = df.pivot("eta", "Regularization", "Nº coefficients")

print(df.head())

ax = sns.heatmap(df)
plt.show()
# Out:
# Regularization    1    2
# eta
# 1.000000e-09    443  444
# 1.000000e-03    409  406
# 1.000000e-02    321  339
# 1.000000e-01    142  271
# 1.000000e+00     63  249
# /tmp/ipykernel_14414/3938517341.py:12: FutureWarning: In a future version of pandas all arguments of DataFrame.pivot will be keyword-only.
#   df = df.pivot("eta", "Regularization", "Nº coefficients")
