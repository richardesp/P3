# %%
import matplotlib.pyplot as plt

# %%
fig = plt.figure()
ax = fig.add_axes([0, 0, 1, 1])
seeds = [1, 2, 3, 4, 5]
mse = [0.019442, 0.019407, 0.020129, 0.019187, 0.020314]
ax.bar(seeds, mse)
ax.set_title('Comparación de resultados de MSE en tests en las distintas semillas')
ax.set_ylabel('MSE')
ax.set_xlabel('Seeds')
plt.show()
